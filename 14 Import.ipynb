# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install django
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 322.2 kB/s eta 0:00:25
# ...

# %%
import random

# %%
random.randint(10,20)
# Out:
# 19

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.DataFrame({"name":["Abhi","Riya"],'age':[20,25]})
# Out:
#    name  age
# 0  Abhi   20
# 1  Riya   25

# %%
import datetime

# %%
 from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 8, 19, 13, 13, 58, 346715)

# %%
a = datetime.now()

# %%
a
# Out:
# datetime.datetime(2025, 8, 19, 13, 15, 5, 76747)

# %%
a.date()
# Out:
# datetime.date(2025, 8, 19)

# %%
a.day
# Out:
# 19

# %%
help(a.hour)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %%
a.max
# Out:
# datetime.datetime(9999, 12, 31, 23, 59, 59, 999999)

# %%
a.min
# Out:
# datetime.datetime(1, 1, 1, 0, 0)

# %%
datetime.date(a)
# Out:
# datetime.date(2025, 8, 19)

# %%
datetime.time(a)
# Out:
# datetime.time(13, 15, 5, 76747)

# %%
d = datetime(2005, 8, 15)

# %%
d
# Out:
# datetime.datetime(2005, 8, 15, 0, 0)

# %%
datetime.strftime(datetime.now(), "%d %B %Y")
# Out:
# '19 August 2025'

# %%
random.choice(["a","b","c","d"])
# Out:
# 'd'
